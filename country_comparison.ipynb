# %%
import numpy as np 
import pandas as pd 
import os
import matplotlib.pyplot as plt
#import seaborn as sns
#import plotly.express as px

# %%
countries_df=pd.read_csv('Resources/country_comparison_large_dataset.csv')
countries_df
# Out:
#        Country  Year  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 0          USA  2000                   20.87                  65455.0
# 1       Russia  2000                    1.64                  10923.0
# 2       Canada  2000                    1.65                  47932.0
# 3        China  2000                   13.64                  10060.0
# 4        India  2000                    2.98                   2102.1
# ..         ...   ...                     ...                      ...
# 139     Russia  2023                    1.64                  10978.0
# 140     Canada  2023                    1.73                  44804.0
# 141      China  2023                   13.72                   9870.0
# 142      India  2023                    2.79                   2070.6
# 143  Australia  2023                    1.27                  51304.0
#
#      Inflation Rate (%)  Population (in Millions)  Population Growth Rate (%)  \
# 0                  2.28                    330.34                        0.58
# 1                  3.25                    141.81                        0.10
# 2                  1.96                     36.63                        0.90
# 3                  2.43                   1446.93                        0.31
# 4                  4.87                   1313.76                        1.04
# ..                  ...                       ...                         ...
# 139                3.20                    138.04                        0.10
# 140                1.88                     35.59                        0.93
# 141                2.29                   1407.79                        0.29
# 142                4.70                   1411.74                        1.03
# 143                1.54                     24.38                        1.36
#
#      Urban Population (%)  Life Expectancy (Years)  \
# 0                   83.42                    78.39
# 1                   72.67                    69.91
# 2                   79.54                    84.60
# 3                   58.56                    76.09
# 4                   34.09                    68.78
# ..                    ...                      ...
# 139                 71.56                    73.47
# 140                 83.11                    79.17
# 141                 61.86                    73.10
# 142                 34.05                    70.09
# 143                 84.37                    83.40
#
#      Healthcare Expenditure per Capita (USD)  ...  Poverty Rate (%)  \
# 0                                   11209.00  ...             10.98
# 1                                     534.45  ...             12.89
# 2                                    5113.50  ...              9.46
# 3                                     459.00  ...              2.04
# 4                                      76.07  ...             22.25
# ..                                       ...  ...               ...
# 139                                   539.70  ...             12.36
# 140                                  5139.75  ...              9.24
# 141                                   430.20  ...              1.92
# 142                                    76.07  ...             21.94
# 143                                  5434.00  ...              9.99
#
#      Number of International Visitors (in Millions)  \
# 0                                             80.80
# 1                                             24.70
# 2                                             22.33
# 3                                             62.20
# 4                                             11.25
# ..                                              ...
# 139                                           24.55
# 140                                           21.32
# 141                                           64.67
# 142                                           10.74
# 143                                            9.77
#
#      Tourism Revenue (in Billion USD)  Agricultural Land (%)  \
# 0                              210.98                  42.37
# 1                               36.47                  12.53
# 2                               29.52                   7.22
# 3                              115.80                  54.00
# 4                               29.12                  57.60
# ..                                ...                    ...
# 139                             35.28                  12.54
# 140                             29.13                   6.96
# 141                            116.76                  56.54
# 142                             28.00                  57.36
# 143                             58.26                  53.80
#
#      Unemployment Rate (%)  Labor Force Participation Rate (%)  \
# 0                     3.55                               65.52
# 1                     4.63                               57.54
# 2                     5.43                               65.06
# 3                     3.68                               63.13
# 4                     7.31                               52.10
# ..                     ...                                 ...
# 139                   4.69                               58.62
# 140                   5.44                               64.61
# 141                   3.58                               65.77
# 142                   7.16                               48.25
# 143                   4.75                               69.23
#
#      Crime Rate (per 100,000)  Corruption Perception Index  \
# 0                      287.40                        67.41
# 1                      497.50                        30.90
# 2                      795.20                        74.74
# 3                      102.90                        41.75
# 4                      245.25                        40.12
# ..                        ...                          ...
# 139                    477.50                        31.02
# 140                    800.80                        72.37
# 141                     95.30                        43.22
# 142                    240.75                        41.36
# 143                    910.80                        75.92
#
#      Freedom of Press Index  Voting Participation Rate (%)
# 0                     45.27                          68.81
# 1                    146.10                          65.00
# 2                     16.42                          63.00
# 3                    185.32                          72.14
# 4                    136.36                          67.65
# ..                      ...                            ...
# 139                  150.15                          65.33
# 140                   15.52                          62.28
# 141                  184.26                          71.14
# 142                  133.28                          66.20
# 143                   25.88                          94.39
#
# [144 rows x 36 columns]

# %%
countries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 36 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Country                                         144 non-null    object
#  1   Year                                            144 non-null    int64
#  2   GDP (in Trillions USD)                          144 non-null    float64
#  3   GDP per Capita (in USD)                         144 non-null    float64
#  4   Inflation Rate (%)                              144 non-null    float64
#  5   Population (in Millions)                        144 non-null    float64
#  6   Population Growth Rate (%)                      144 non-null    float64
#  7   Urban Population (%)                            144 non-null    float64
#  8   Life Expectancy (Years)                         144 non-null    float64
#  9   Healthcare Expenditure per Capita (USD)         144 non-null    float64
#  10  Doctor-to-Patient Ratio                         144 non-null    float64
#  11  Literacy Rate (%)                               144 non-null    float64
#  12  Education Expenditure as % of GDP               144 non-null    float64
#  13  Internet Penetration (%)                        144 non-null    float64
#  14  Smartphone Adoption (%)                         144 non-null    float64
#  15  Energy Consumption (TWh)                        144 non-null    float64
#  16  Renewable Energy Share (%)                      144 non-null    float64
#  17  Military Expenditure (in Billion USD)           144 non-null    float64
#  18  Number of Active Military Personnel             144 non-null    float64
#  19  CO2 Emissions (Million Metric Tons)             144 non-null    float64
#  20  Forest Coverage (%)                             144 non-null    float64
#  21  Number of Airports                              144 non-null    float64
#  22  Road Network Length (in km)                     144 non-null    float64
#  23  Public Transport Usage (%)                      144 non-null    float64
#  24  Human Development Index (HDI)                   144 non-null    float64
#  25  Gender Equality Index                           144 non-null    float64
#  26  Poverty Rate (%)                                144 non-null    float64
#  27  Number of International Visitors (in Millions)  144 non-null    float64
#  28  Tourism Revenue (in Billion USD)                144 non-null    float64
#  29  Agricultural Land (%)                           144 non-null    float64
#  30  Unemployment Rate (%)                           144 non-null    float64
#  31  Labor Force Participation Rate (%)              144 non-null    float64
#  32  Crime Rate (per 100,000)                        144 non-null    float64
#  33  Corruption Perception Index                     144 non-null    float64
#  34  Freedom of Press Index                          144 non-null    float64
#  35  Voting Participation Rate (%)                   144 non-null    float64
# dtypes: float64(34), int64(1), object(1)
# memory usage: 40.6+ KB

# %%
countries_df_no_nulls = countries_df.dropna()
countries_df_no_nulls
# Out:
#        Country  Year  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 0          USA  2000                   20.87                  65455.0
# 1       Russia  2000                    1.64                  10923.0
# 2       Canada  2000                    1.65                  47932.0
# 3        China  2000                   13.64                  10060.0
# 4        India  2000                    2.98                   2102.1
# ..         ...   ...                     ...                      ...
# 139     Russia  2023                    1.64                  10978.0
# 140     Canada  2023                    1.73                  44804.0
# 141      China  2023                   13.72                   9870.0
# 142      India  2023                    2.79                   2070.6
# 143  Australia  2023                    1.27                  51304.0
#
#      Inflation Rate (%)  Population (in Millions)  Population Growth Rate (%)  \
# 0                  2.28                    330.34                        0.58
# 1                  3.25                    141.81                        0.10
# 2                  1.96                     36.63                        0.90
# 3                  2.43                   1446.93                        0.31
# 4                  4.87                   1313.76                        1.04
# ..                  ...                       ...                         ...
# 139                3.20                    138.04                        0.10
# 140                1.88                     35.59                        0.93
# 141                2.29                   1407.79                        0.29
# 142                4.70                   1411.74                        1.03
# 143                1.54                     24.38                        1.36
#
#      Urban Population (%)  Life Expectancy (Years)  \
# 0                   83.42                    78.39
# 1                   72.67                    69.91
# 2                   79.54                    84.60
# 3                   58.56                    76.09
# 4                   34.09                    68.78
# ..                    ...                      ...
# 139                 71.56                    73.47
# 140                 83.11                    79.17
# 141                 61.86                    73.10
# 142                 34.05                    70.09
# 143                 84.37                    83.40
#
#      Healthcare Expenditure per Capita (USD)  ...  Poverty Rate (%)  \
# 0                                   11209.00  ...             10.98
# 1                                     534.45  ...             12.89
# 2                                    5113.50  ...              9.46
# 3                                     459.00  ...              2.04
# 4                                      76.07  ...             22.25
# ..                                       ...  ...               ...
# 139                                   539.70  ...             12.36
# 140                                  5139.75  ...              9.24
# 141                                   430.20  ...              1.92
# 142                                    76.07  ...             21.94
# 143                                  5434.00  ...              9.99
#
#      Number of International Visitors (in Millions)  \
# 0                                             80.80
# 1                                             24.70
# 2                                             22.33
# 3                                             62.20
# 4                                             11.25
# ..                                              ...
# 139                                           24.55
# 140                                           21.32
# 141                                           64.67
# 142                                           10.74
# 143                                            9.77
#
#      Tourism Revenue (in Billion USD)  Agricultural Land (%)  \
# 0                              210.98                  42.37
# 1                               36.47                  12.53
# 2                               29.52                   7.22
# 3                              115.80                  54.00
# 4                               29.12                  57.60
# ..                                ...                    ...
# 139                             35.28                  12.54
# 140                             29.13                   6.96
# 141                            116.76                  56.54
# 142                             28.00                  57.36
# 143                             58.26                  53.80
#
#      Unemployment Rate (%)  Labor Force Participation Rate (%)  \
# 0                     3.55                               65.52
# 1                     4.63                               57.54
# 2                     5.43                               65.06
# 3                     3.68                               63.13
# 4                     7.31                               52.10
# ..                     ...                                 ...
# 139                   4.69                               58.62
# 140                   5.44                               64.61
# 141                   3.58                               65.77
# 142                   7.16                               48.25
# 143                   4.75                               69.23
#
#      Crime Rate (per 100,000)  Corruption Perception Index  \
# 0                      287.40                        67.41
# 1                      497.50                        30.90
# 2                      795.20                        74.74
# 3                      102.90                        41.75
# 4                      245.25                        40.12
# ..                        ...                          ...
# 139                    477.50                        31.02
# 140                    800.80                        72.37
# 141                     95.30                        43.22
# 142                    240.75                        41.36
# 143                    910.80                        75.92
#
#      Freedom of Press Index  Voting Participation Rate (%)
# 0                     45.27                          68.81
# 1                    146.10                          65.00
# 2                     16.42                          63.00
# 3                    185.32                          72.14
# 4                    136.36                          67.65
# ..                      ...                            ...
# 139                  150.15                          65.33
# 140                   15.52                          62.28
# 141                  184.26                          71.14
# 142                  133.28                          66.20
# 143                   25.88                          94.39
#
# [144 rows x 36 columns]

# %%
countries_df = pd.read_csv('Resources/country_comparison_large_dataset.csv')

# Calculate the mean healthcare expenditure before and after 2020 for each country
def calculate_mean_health_expenditure(df):
    # Separate data before and after 2020
    before_2020 = df[df['Year'] < 2020].groupby('Country')['Healthcare Expenditure per Capita (USD)'].mean()
    after_2020 = df[df['Year'] >= 2020].groupby('Country')['Healthcare Expenditure per Capita (USD)'].mean()
    
    # Merge the two means into a DataFrame
    mean_health_expenditure = pd.DataFrame({
        'Mean Healthcare Expenditure Before 2020': before_2020,
        'Mean Healthcare Expenditure After 2020': after_2020
    })
    
    return mean_health_expenditure

# Apply the function to get the mean healthcare expenditures
mean_health_expenditure = calculate_mean_health_expenditure(countries_df)

# Merge the mean values back into the original DataFrame
countries_df_2 = countries_df.merge(mean_health_expenditure, on='Country', how='left')

# Display the updated DataFrame with new columns
display(countries_df_2)
# Out:
#        Country  Year  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 0          USA  2000                   20.87                  65455.0
# 1       Russia  2000                    1.64                  10923.0
# 2       Canada  2000                    1.65                  47932.0
# 3        China  2000                   13.64                  10060.0
# 4        India  2000                    2.98                   2102.1
# ..         ...   ...                     ...                      ...
# 139     Russia  2023                    1.64                  10978.0
# 140     Canada  2023                    1.73                  44804.0
# 141      China  2023                   13.72                   9870.0
# 142      India  2023                    2.79                   2070.6
# 143  Australia  2023                    1.27                  51304.0
#
#      Inflation Rate (%)  Population (in Millions)  Population Growth Rate (%)  \
# 0                  2.28                    330.34                        0.58
# 1                  3.25                    141.81                        0.10
# 2                  1.96                     36.63                        0.90
# 3                  2.43                   1446.93                        0.31
# 4                  4.87                   1313.76                        1.04
# ..                  ...                       ...                         ...
# 139                3.20                    138.04                        0.10
# 140                1.88                     35.59                        0.93
# 141                2.29                   1407.79                        0.29
# 142                4.70                   1411.74                        1.03
# 143                1.54                     24.38                        1.36
#
#      Urban Population (%)  Life Expectancy (Years)  \
# 0                   83.42                    78.39
# 1                   72.67                    69.91
# 2                   79.54                    84.60
# 3                   58.56                    76.09
# 4                   34.09                    68.78
# ..                    ...                      ...
# 139                 71.56                    73.47
# 140                 83.11                    79.17
# 141                 61.86                    73.10
# 142                 34.05                    70.09
# 143                 84.37                    83.40
#
#      Healthcare Expenditure per Capita (USD)  ...  \
# 0                                   11209.00  ...
# 1                                     534.45  ...
# 2                                    5113.50  ...
# 3                                     459.00  ...
# 4                                      76.07  ...
# ..                                       ...  ...
# 139                                   539.70  ...
# 140                                  5139.75  ...
# 141                                   430.20  ...
# 142                                    76.07  ...
# 143                                  5434.00  ...
#
#      Tourism Revenue (in Billion USD)  Agricultural Land (%)  \
# 0                              210.98                  42.37
# 1                               36.47                  12.53
# 2                               29.52                   7.22
# 3                              115.80                  54.00
# 4                               29.12                  57.60
# ..                                ...                    ...
# 139                             35.28                  12.54
# 140                             29.13                   6.96
# 141                            116.76                  56.54
# 142                             28.00                  57.36
# 143                             58.26                  53.80
#
#      Unemployment Rate (%)  Labor Force Participation Rate (%)  \
# 0                     3.55                               65.52
# 1                     4.63                               57.54
# 2                     5.43                               65.06
# 3                     3.68                               63.13
# 4                     7.31                               52.10
# ..                     ...                                 ...
# 139                   4.69                               58.62
# 140                   5.44                               64.61
# 141                   3.58                               65.77
# 142                   7.16                               48.25
# 143                   4.75                               69.23
#
#      Crime Rate (per 100,000)  Corruption Perception Index  \
# 0                      287.40                        67.41
# 1                      497.50                        30.90
# 2                      795.20                        74.74
# 3                      102.90                        41.75
# 4                      245.25                        40.12
# ..                        ...                          ...
# 139                    477.50                        31.02
# 140                    800.80                        72.37
# 141                     95.30                        43.22
# 142                    240.75                        41.36
# 143                    910.80                        75.92
#
#      Freedom of Press Index  Voting Participation Rate (%)  \
# 0                     45.27                          68.81
# 1                    146.10                          65.00
# 2                     16.42                          63.00
# 3                    185.32                          72.14
# 4                    136.36                          67.65
# ..                      ...                            ...
# 139                  150.15                          65.33
# 140                   15.52                          62.28
# 141                  184.26                          71.14
# 142                  133.28                          66.20
# 143                   25.88                          94.39
#
#      Mean Healthcare Expenditure Before 2020  \
# 0                                 10960.4000
# 1                                   528.9895
# 2                                  5246.5875
# 3                                   448.8075
# 4                                    72.8260
# ..                                       ...
# 139                                 528.9895
# 140                                5246.5875
# 141                                 448.8075
# 142                                  72.8260
# 143                                5221.0600
#
#      Mean Healthcare Expenditure After 2020
# 0                                 10953.250
# 1                                   538.650
# 2                                  5236.875
# 3                                   439.875
# 4                                    74.335
# ..                                      ...
# 139                                 538.650
# 140                                5236.875
# 141                                 439.875
# 142                                  74.335
# 143                                5270.200
#
# [144 rows x 38 columns]

# %%
# Define the list of columns you want to keep
country_columns_to_keep = [
    'Country', 'Year', 'GDP (in Trillions USD)', 'GDP per Capita (in USD)', 
    'Inflation Rate (%)', 'Population (in Millions)', 'Population Growth Rate (%)', 
    'Life Expectancy (Years)', 'Healthcare Expenditure per Capita (USD)', 
    'Doctor-to-Patient Ratio', 'Unemployment Rate (%)', 
    'Labor Force Participation Rate (%)', 'Crime Rate (per 100,000)', 
    'Mean Healthcare Expenditure Before 2020', 'Mean Healthcare Expenditure After 2020'
]

# Update the DataFrame to include only the specified columns
countries_cleaned_df = countries_df_2[country_columns_to_keep]

# Display the updated DataFrame
display(countries_cleaned_df)
# Out:
#        Country  Year  GDP (in Trillions USD)  GDP per Capita (in USD)  \
# 0          USA  2000                   20.87                  65455.0
# 1       Russia  2000                    1.64                  10923.0
# 2       Canada  2000                    1.65                  47932.0
# 3        China  2000                   13.64                  10060.0
# 4        India  2000                    2.98                   2102.1
# ..         ...   ...                     ...                      ...
# 139     Russia  2023                    1.64                  10978.0
# 140     Canada  2023                    1.73                  44804.0
# 141      China  2023                   13.72                   9870.0
# 142      India  2023                    2.79                   2070.6
# 143  Australia  2023                    1.27                  51304.0
#
#      Inflation Rate (%)  Population (in Millions)  Population Growth Rate (%)  \
# 0                  2.28                    330.34                        0.58
# 1                  3.25                    141.81                        0.10
# 2                  1.96                     36.63                        0.90
# 3                  2.43                   1446.93                        0.31
# 4                  4.87                   1313.76                        1.04
# ..                  ...                       ...                         ...
# 139                3.20                    138.04                        0.10
# 140                1.88                     35.59                        0.93
# 141                2.29                   1407.79                        0.29
# 142                4.70                   1411.74                        1.03
# 143                1.54                     24.38                        1.36
#
#      Life Expectancy (Years)  Healthcare Expenditure per Capita (USD)  \
# 0                      78.39                                 11209.00
# 1                      69.91                                   534.45
# 2                      84.60                                  5113.50
# 3                      76.09                                   459.00
# 4                      68.78                                    76.07
# ..                       ...                                      ...
# 139                    73.47                                   539.70
# 140                    79.17                                  5139.75
# 141                    73.10                                   430.20
# 142                    70.09                                    76.07
# 143                    83.40                                  5434.00
#
#      Doctor-to-Patient Ratio  Unemployment Rate (%)  \
# 0                       2.60                   3.55
# 1                       4.05                   4.63
# 2                       2.84                   5.43
# 3                       1.86                   3.68
# 4                       0.86                   7.31
# ..                       ...                    ...
# 139                     4.14                   4.69
# 140                     2.78                   5.44
# 141                     1.81                   3.58
# 142                     0.93                   7.16
# 143                     3.53                   4.75
#
#      Labor Force Participation Rate (%)  Crime Rate (per 100,000)  \
# 0                                 65.52                    287.40
# 1                                 57.54                    497.50
# 2                                 65.06                    795.20
# 3                                 63.13                    102.90
# 4                                 52.10                    245.25
# ..                                  ...                       ...
# 139                               58.62                    477.50
# 140                               64.61                    800.80
# 141                               65.77                     95.30
# 142                               48.25                    240.75
# 143                               69.23                    910.80
#
#      Mean Healthcare Expenditure Before 2020  \
# 0                                 10960.4000
# 1                                   528.9895
# 2                                  5246.5875
# 3                                   448.8075
# 4                                    72.8260
# ..                                       ...
# 139                                 528.9895
# 140                                5246.5875
# 141                                 448.8075
# 142                                  72.8260
# 143                                5221.0600
#
#      Mean Healthcare Expenditure After 2020
# 0                                 10953.250
# 1                                   538.650
# 2                                  5236.875
# 3                                   439.875
# 4                                    74.335
# ..                                      ...
# 139                                 538.650
# 140                                5236.875
# 141                                 439.875
# 142                                  74.335
# 143                                5270.200
#
# [144 rows x 15 columns]

# %%
# Ensure the 'resources' folder exists
os.makedirs('resources', exist_ok=True)

# Save the DataFrame to a CSV file in the 'resources' folder
countries_cleaned_df.to_csv('resources/countries_cleaned_dataset.csv', index=False)

print("DataFrame saved as 'countries_cleaned_dataset.csv' in the 'resources' folder.")
# Out:
# DataFrame saved as 'countries_cleaned_dataset.csv' in the 'resources' folder.

# %%
countries_df=pd.read_csv('Resources/countries_cleaned_dataset.csv')

# %%
row1 = {}
filtered_df = countries_df.drop(columns=['Country', 'Year'])
stats = filtered_df.columns
for stat in stats:
    earliest = countries_df.loc[(countries_df['Country'] == 'USA') & (countries_df['Year'] == 2019), stat]
    latest = countries_df.loc[(countries_df['Country'] == 'USA') & (countries_df['Year'] == 2020), stat]
    row1[stat] = ((latest.iloc[0] - earliest.iloc[0])/earliest.iloc[0])*100
row1['Country'] = 'USA'
new_row_df = pd.DataFrame([row1])
new_row_df
# Out:
#    GDP (in Trillions USD)  GDP per Capita (in USD)  Inflation Rate (%)  \
# 0                2.881041                -1.846154           -0.877193
#
#    Population (in Millions)  Population Growth Rate (%)  \
# 0                  4.995442                   -4.918033
#
#    Life Expectancy (Years)  Healthcare Expenditure per Capita (USD)  \
# 0                  3.42457                                -3.389831
#
#    Doctor-to-Patient Ratio  Unemployment Rate (%)  \
# 0                 1.550388              -5.699482
#
#    Labor Force Participation Rate (%)  Crime Rate (per 100,000)  \
# 0                           -1.252678                 -1.761252
#
#    Mean Healthcare Expenditure Before 2020  \
# 0                                      0.0
#
#    Mean Healthcare Expenditure After 2020 Country
# 0                                     0.0     USA

# %%
row1 = {}
filtered_df = countries_df.drop(columns=['Country', 'Year'])
stats = filtered_df.columns
for stat in stats:
    earliest = countries_df.loc[(countries_df['Country'] == 'Russia') & (countries_df['Year'] == 2019), stat]
    latest = countries_df.loc[(countries_df['Country'] == 'Russia') & (countries_df['Year'] == 2020), stat]
    row1[stat] = ((latest.iloc[0] - earliest.iloc[0])/earliest.iloc[0])*100
row1['Country'] = 'Russia'
new_row_df2 = pd.DataFrame([row1])
new_row_df2
# Out:
#    GDP (in Trillions USD)  GDP per Capita (in USD)  Inflation Rate (%)  \
# 0                5.031447                 7.246377           -2.515723
#
#    Population (in Millions)  Population Growth Rate (%)  \
# 0                 -1.417004                         0.0
#
#    Life Expectancy (Years)  Healthcare Expenditure per Capita (USD)  \
# 0                 2.988048                                -0.287272
#
#    Doctor-to-Patient Ratio  Unemployment Rate (%)  \
# 0                 0.729927               1.354402
#
#    Labor Force Participation Rate (%)  Crime Rate (per 100,000)  \
# 0                           -0.791296                   5.60166
#
#    Mean Healthcare Expenditure Before 2020  \
# 0                                      0.0
#
#    Mean Healthcare Expenditure After 2020 Country
# 0                                     0.0  Russia

# %%
row1 = {}
filtered_df = countries_df.drop(columns=['Country', 'Year'])
stats = filtered_df.columns
for stat in stats:
    earliest = countries_df.loc[(countries_df['Country'] == 'Canada') & (countries_df['Year'] == 2019), stat]
    latest = countries_df.loc[(countries_df['Country'] == 'Canada') & (countries_df['Year'] == 2020), stat]
    row1[stat] = ((latest.iloc[0] - earliest.iloc[0])/earliest.iloc[0])*100
row1['Country'] = 'Canada'
new_row_df3 = pd.DataFrame([row1])
new_row_df3
# Out:
#    GDP (in Trillions USD)  GDP per Capita (in USD)  Inflation Rate (%)  \
# 0               -7.734807                -2.663934            0.543478
#
#    Population (in Millions)  Population Growth Rate (%)  \
# 0                  0.620068                    1.149425
#
#    Life Expectancy (Years)  Healthcare Expenditure per Capita (USD)  \
# 0                -4.623669                                 3.014553
#
#    Doctor-to-Patient Ratio  Unemployment Rate (%)  \
# 0                -1.324503               5.607477
#
#    Labor Force Participation Rate (%)  Crime Rate (per 100,000)  \
# 0                           -4.830406                 -3.115871
#
#    Mean Healthcare Expenditure Before 2020  \
# 0                                      0.0
#
#    Mean Healthcare Expenditure After 2020 Country
# 0                                     0.0  Canada

# %%
row1 = {}
filtered_df = countries_df.drop(columns=['Country', 'Year'])
stats = filtered_df.columns
for stat in stats:
    earliest = countries_df.loc[(countries_df['Country'] == 'China') & (countries_df['Year'] == 2019), stat]
    latest = countries_df.loc[(countries_df['Country'] == 'China') & (countries_df['Year'] == 2020), stat]
    row1[stat] = ((latest.iloc[0] - earliest.iloc[0])/earliest.iloc[0])*100
row1['Country'] = 'China'
new_row_df4 = pd.DataFrame([row1])
new_row_df4
# Out:
#    GDP (in Trillions USD)  GDP per Capita (in USD)  Inflation Rate (%)  \
# 0               -4.197698                -1.412714            1.229508
#
#    Population (in Millions)  Population Growth Rate (%)  \
# 0                 -0.521377                   -3.333333
#
#    Life Expectancy (Years)  Healthcare Expenditure per Capita (USD)  \
# 0                 6.822165                                 2.564103
#
#    Doctor-to-Patient Ratio  Unemployment Rate (%)  \
# 0                 5.649718               5.247813
#
#    Labor Force Participation Rate (%)  Crime Rate (per 100,000)  \
# 0                            7.294041                 -8.595989
#
#    Mean Healthcare Expenditure Before 2020  \
# 0                                      0.0
#
#    Mean Healthcare Expenditure After 2020 Country
# 0                                     0.0   China

# %%
row1 = {}
filtered_df = countries_df.drop(columns=['Country', 'Year'])
stats = filtered_df.columns
for stat in stats:
    earliest = countries_df.loc[(countries_df['Country'] == 'India') & (countries_df['Year'] == 2019), stat]
    latest = countries_df.loc[(countries_df['Country'] == 'India') & (countries_df['Year'] == 2020), stat]
    row1[stat] = ((latest.iloc[0] - earliest.iloc[0])/earliest.iloc[0])*100
row1['Country'] = 'India'
new_row_df5 = pd.DataFrame([row1])
new_row_df5
# Out:
#    GDP (in Trillions USD)  GDP per Capita (in USD)  Inflation Rate (%)  \
# 0               -5.479452                -4.109589           -6.772908
#
#    Population (in Millions)  Population Growth Rate (%)  \
# 0                  5.925156                       3.125
#
#    Life Expectancy (Years)  Healthcare Expenditure per Capita (USD)  \
# 0                 1.872499                                 6.019307
#
#    Doctor-to-Patient Ratio  Unemployment Rate (%)  \
# 0                 3.448276               1.540616
#
#    Labor Force Participation Rate (%)  Crime Rate (per 100,000)  \
# 0                            4.824121                  1.789264
#
#    Mean Healthcare Expenditure Before 2020  \
# 0                                      0.0
#
#    Mean Healthcare Expenditure After 2020 Country
# 0                                     0.0   India

# %%
row1 = {}
filtered_df = countries_df.drop(columns=['Country', 'Year'])
stats = filtered_df.columns
for stat in stats:
    earliest = countries_df.loc[(countries_df['Country'] == 'Australia') & (countries_df['Year'] == 2019), stat]
    latest = countries_df.loc[(countries_cleaned_df['Country'] == 'Australia') & (countries_df['Year'] == 2020), stat]
    row1[stat] = ((latest.iloc[0] - earliest.iloc[0])/earliest.iloc[0])*100
row1['Country'] = 'Australia'
new_row_df6 = pd.DataFrame([row1])
new_row_df6
# Out:
#    GDP (in Trillions USD)  GDP per Capita (in USD)  Inflation Rate (%)  \
# 0               -8.633094                 1.752577            7.586207
#
#    Population (in Millions)  Population Growth Rate (%)  \
# 0                  1.171875                   -3.703704
#
#    Life Expectancy (Years)  Healthcare Expenditure per Capita (USD)  \
# 0                -6.732765                                -3.625954
#
#    Doctor-to-Patient Ratio  Unemployment Rate (%)  \
# 0                 0.564972               4.703476
#
#    Labor Force Participation Rate (%)  Crime Rate (per 100,000)  \
# 0                            5.478166                 -2.017291
#
#    Mean Healthcare Expenditure Before 2020  \
# 0                                      0.0
#
#    Mean Healthcare Expenditure After 2020    Country
# 0                                     0.0  Australia

# %%
growth_rate_df = pd.concat([new_row_df, new_row_df2, new_row_df3,new_row_df4,new_row_df5,new_row_df6], ignore_index=True)
# Drop the specified columns
growth_rate_df = growth_rate_df.drop(columns=['Mean Healthcare Expenditure Before 2020', 'Mean Healthcare Expenditure After 2020'])

# Move the 'Country' column to the far left
country_column = growth_rate_df.pop('Country')
growth_rate_df.insert(0, 'Country', country_column)
growth_rate_df['Year Range'] = '2019-2020 (Covid-19)'
year_range_column = growth_rate_df.pop('Year Range')
growth_rate_df.insert(0, 'Year Range', year_range_column)

growth_rate_df
# Out:
#              Year Range    Country  GDP (in Trillions USD)  \
# 0  2019-2020 (Covid-19)        USA                2.881041
# 1  2019-2020 (Covid-19)     Russia                5.031447
# 2  2019-2020 (Covid-19)     Canada               -7.734807
# 3  2019-2020 (Covid-19)      China               -4.197698
# 4  2019-2020 (Covid-19)      India               -5.479452
# 5  2019-2020 (Covid-19)  Australia               -8.633094
#
#    GDP per Capita (in USD)  Inflation Rate (%)  Population (in Millions)  \
# 0                -1.846154           -0.877193                  4.995442
# 1                 7.246377           -2.515723                 -1.417004
# 2                -2.663934            0.543478                  0.620068
# 3                -1.412714            1.229508                 -0.521377
# 4                -4.109589           -6.772908                  5.925156
# 5                 1.752577            7.586207                  1.171875
#
#    Population Growth Rate (%)  Life Expectancy (Years)  \
# 0                   -4.918033                 3.424570
# 1                    0.000000                 2.988048
# 2                    1.149425                -4.623669
# 3                   -3.333333                 6.822165
# 4                    3.125000                 1.872499
# 5                   -3.703704                -6.732765
#
#    Healthcare Expenditure per Capita (USD)  Doctor-to-Patient Ratio  \
# 0                                -3.389831                 1.550388
# 1                                -0.287272                 0.729927
# 2                                 3.014553                -1.324503
# 3                                 2.564103                 5.649718
# 4                                 6.019307                 3.448276
# 5                                -3.625954                 0.564972
#
#    Unemployment Rate (%)  Labor Force Participation Rate (%)  \
# 0              -5.699482                           -1.252678
# 1               1.354402                           -0.791296
# 2               5.607477                           -4.830406
# 3               5.247813                            7.294041
# 4               1.540616                            4.824121
# 5               4.703476                            5.478166
#
#    Crime Rate (per 100,000)
# 0                 -1.761252
# 1                  5.601660
# 2                 -3.115871
# 3                 -8.595989
# 4                  1.789264
# 5                 -2.017291

# %%
json_data = countries_df.to_json(orient="records", indent=4)

output_path = "Resources/percentages_data.json"
growth_rate_df.to_json(output_path, orient="records", indent=4)

# %%
# Ensure the 'resources' folder exists
os.makedirs('resources', exist_ok=True)

# Save the DataFrame to a CSV file in the 'resources' folder
growth_rate_df.to_csv('resources/growth_rate_df.csv', index=False)

print("DataFrame saved as 'growth_rate_df.csv' in the 'resources' folder.")
# Out:
# DataFrame saved as 'growth_rate_df.csv' in the 'resources' folder.

# %%
# Filter for only 2011 and 2023 data points
data_filtered = countries_df[countries_df['Year'].isin([2011, 2023])]

# Pivot data to organize by year for healthcare expenditure per capita
healthcare_expenditure = data_filtered.pivot(index='Country', columns='Year', values='Healthcare Expenditure per Capita (USD)')

# Drop rows with missing data for either 2011 or 2023
healthcare_expenditure.dropna(inplace=True)

# Calculate the absolute change in healthcare expenditure from 2011 to 2023
healthcare_expenditure['Healthcare Expenditure Change'] = healthcare_expenditure[2023] - healthcare_expenditure[2011]

# Sort the data by the largest absolute changes
healthcare_expenditure_change_sorted = healthcare_expenditure[['Healthcare Expenditure Change']].sort_values(by='Healthcare Expenditure Change', ascending=False)

# Display the countries with the most significant changes in healthcare expenditure per capita
healthcare_expenditure_change_sorted.head(6)
# Out:
# Year       Healthcare Expenditure Change
# Country
# Australia                         265.20
# USA                                99.00
# India                               0.95
# Russia                             -6.82
# China                             -30.60
# Canada                           -336.00

# %%
# Pivot data for unemployment rate
unemployment_rate = data_filtered.pivot(index='Country', columns='Year', values='Unemployment Rate (%)')

# Drop rows with missing data for either 2011 or 2023
unemployment_rate.dropna(inplace=True)

# Calculate the absolute change from 2011 to 2023
unemployment_rate['Unemployment Rate Change'] = unemployment_rate[2023] - unemployment_rate[2011]

# Sort by the highest change
unemployment_rate_change_sorted = unemployment_rate[['Unemployment Rate Change']].sort_values(by='Unemployment Rate Change', ascending=False)

# Display top countries with the highest changes
unemployment_rate_change_sorted.head(6)
# Out:
# Year       Unemployment Rate Change
# Country
# China                          0.02
# Russia                        -0.07
# USA                           -0.21
# India                         -0.24
# Canada                        -0.28
# Australia                     -0.29

# %%
# Filter for only 2011 and 2023 data points
data_filtered_2 = countries_df[countries_df['Year'].isin([2011, 2023])]

# Pivot data to organize by year for inflation rate
inflation_rate = data_filtered_2.pivot(index='Country', columns='Year', values='Inflation Rate (%)')

# Drop rows with missing data for either 2011 or 2023
inflation_rate.dropna(inplace=True)

# Calculate the absolute change in inflation rate from 2011 to 2023
inflation_rate['Inflation Rate Change'] = inflation_rate[2023] - inflation_rate[2011]

# Sort the data by the largest absolute changes
inflation_rate_change_sorted = inflation_rate[['Inflation Rate Change']].sort_values(by='Inflation Rate Change', ascending=False)

# Display the countries with the most significant changes in inflation rate
inflation_rate_change_sorted.head(6)
# Out:
# Year       Inflation Rate Change
# Country
# Russia                      0.24
# Canada                      0.03
# Australia                   0.00
# USA                        -0.12
# India                      -0.15
# China                      -0.21

# %%
def create_new_row(dataset, year1, year2, country):
    row = {}
    filtered_df = dataset.drop(columns=['Country', 'Year'])
    stats = filtered_df.columns
    for stat in stats:
        earliest = dataset.loc[(countries_df['Country'] == country) & (countries_df['Year'] == year1), stat]
        latest = countries_df.loc[(countries_df['Country'] == country) & (countries_df['Year'] == year2), stat]
        row[stat] = ((latest.iloc[0] - earliest.iloc[0])/earliest.iloc[0])*100
    row['Country'] = country
    new_row_df = pd.DataFrame([row])
    return new_row_df

# %%
def add_six_more_rows(dataset, year1, year2, description):
    countries = ['USA', 'Russia', 'Canada', 'China', 'India', 'Australia']
    new_df = pd.DataFrame()
    for country in countries:
        row = create_new_row(countries_df, year1, year2, country)
        new_df = pd.concat([row, new_df], ignore_index=True)
    new_df = new_df.drop(columns=['Mean Healthcare Expenditure Before 2020', 'Mean Healthcare Expenditure After 2020'])

    # Move the 'Country' column to the far left
    country_column = new_df.pop('Country')
    new_df.insert(0, 'Country', country_column)
    new_df['Year Range'] = f'{year1}-{year2} ({description})'
    year_range_column = new_df.pop('Year Range')
    new_df.insert(0, 'Year Range', year_range_column)
    return new_df

# %%
df = add_six_more_rows(countries_df, 2001, 2002, '9/11 (USA)')
growth_rate_df = pd.concat([growth_rate_df, df], ignore_index=True)

# %%
df = add_six_more_rows(countries_df, 2014, 2016, 'Ebola outbreak')
growth_rate_df = pd.concat([growth_rate_df, df], ignore_index=True)

# %%
df = add_six_more_rows(countries_df, 2007, 2008, 'Finacial Crisis (USA)')
growth_rate_df = pd.concat([growth_rate_df, df], ignore_index=True)

# %%
df = add_six_more_rows(countries_df, 2022, 2023, 'Russian Invasion of Ukraine')
growth_rate_df = pd.concat([growth_rate_df, df], ignore_index=True)

# %%
df = add_six_more_rows(countries_df, 2004, 2005, 'Indian ocean earthquake & tsunami')
growth_rate_df = pd.concat([growth_rate_df, df], ignore_index=True)

# %%
df = add_six_more_rows(countries_df, 2016, 2017, 'Fort McMurray Wildfire')
growth_rate_df = pd.concat([growth_rate_df, df], ignore_index=True)

# %%
df = add_six_more_rows(countries_df, 2009, 2010, 'Swine Flu Pandemic (Global)')
growth_rate_df = pd.concat([growth_rate_df, df], ignore_index=True)

# %%
df = add_six_more_rows(countries_df, 2011, 2023, 'General Trends from 2011 to 2023')
growth_rate_df = pd.concat([growth_rate_df, df], ignore_index=True)

# %%
df = add_six_more_rows(countries_df, 2019, 2023, 'General Trends from Post Covid 2019 to 2023')
growth_rate_df = pd.concat([growth_rate_df, df], ignore_index=True)

# %%
growth_rate_df
# Out:
#                                            Year Range    Country  \
# 0                                2019-2020 (Covid-19)        USA
# 1                                2019-2020 (Covid-19)     Russia
# 2                                2019-2020 (Covid-19)     Canada
# 3                                2019-2020 (Covid-19)      China
# 4                                2019-2020 (Covid-19)      India
# 5                                2019-2020 (Covid-19)  Australia
# 6                              2001-2002 (9/11 (USA))  Australia
# 7                              2001-2002 (9/11 (USA))      India
# 8                              2001-2002 (9/11 (USA))      China
# 9                              2001-2002 (9/11 (USA))     Canada
# 10                             2001-2002 (9/11 (USA))     Russia
# 11                             2001-2002 (9/11 (USA))        USA
# 12                         2014-2016 (Ebola outbreak)  Australia
# 13                         2014-2016 (Ebola outbreak)      India
# 14                         2014-2016 (Ebola outbreak)      China
# 15                         2014-2016 (Ebola outbreak)     Canada
# 16                         2014-2016 (Ebola outbreak)     Russia
# 17                         2014-2016 (Ebola outbreak)        USA
# 18                  2007-2008 (Finacial Crisis (USA))  Australia
# 19                  2007-2008 (Finacial Crisis (USA))      India
# 20                  2007-2008 (Finacial Crisis (USA))      China
# 21                  2007-2008 (Finacial Crisis (USA))     Canada
# 22                  2007-2008 (Finacial Crisis (USA))     Russia
# 23                  2007-2008 (Finacial Crisis (USA))        USA
# 24            2022-2023 (Russian Invasion of Ukraine)  Australia
# 25            2022-2023 (Russian Invasion of Ukraine)      India
# 26            2022-2023 (Russian Invasion of Ukraine)      China
# 27            2022-2023 (Russian Invasion of Ukraine)     Canada
# 28            2022-2023 (Russian Invasion of Ukraine)     Russia
# 29            2022-2023 (Russian Invasion of Ukraine)        USA
# 30      2004-2005 (Indian ocean earthquake & tsunami)  Australia
# 31      2004-2005 (Indian ocean earthquake & tsunami)      India
# 32      2004-2005 (Indian ocean earthquake & tsunami)      China
# 33      2004-2005 (Indian ocean earthquake & tsunami)     Canada
# 34      2004-2005 (Indian ocean earthquake & tsunami)     Russia
# 35      2004-2005 (Indian ocean earthquake & tsunami)        USA
# 36                 2016-2017 (Fort McMurray Wildfire)  Australia
# 37                 2016-2017 (Fort McMurray Wildfire)      India
# 38                 2016-2017 (Fort McMurray Wildfire)      China
# 39                 2016-2017 (Fort McMurray Wildfire)     Canada
# 40                 2016-2017 (Fort McMurray Wildfire)     Russia
# 41                 2016-2017 (Fort McMurray Wildfire)        USA
# 42            2009-2010 (Swine Flu Pandemic (Global))  Australia
# 43            2009-2010 (Swine Flu Pandemic (Global))      India
# 44            2009-2010 (Swine Flu Pandemic (Global))      China
# 45            2009-2010 (Swine Flu Pandemic (Global))     Canada
# 46            2009-2010 (Swine Flu Pandemic (Global))     Russia
# 47            2009-2010 (Swine Flu Pandemic (Global))        USA
# 48       2011-2023 (General Trends from 2011 to 2023)  Australia
# 49       2011-2023 (General Trends from 2011 to 2023)      India
# 50       2011-2023 (General Trends from 2011 to 2023)      China
# 51       2011-2023 (General Trends from 2011 to 2023)     Canada
# 52       2011-2023 (General Trends from 2011 to 2023)     Russia
# 53       2011-2023 (General Trends from 2011 to 2023)        USA
# 54  2019-2023 (General Trends from Post Covid 2019...  Australia
# 55  2019-2023 (General Trends from Post Covid 2019...      India
# 56  2019-2023 (General Trends from Post Covid 2019...      China
# 57  2019-2023 (General Trends from Post Covid 2019...     Canada
# 58  2019-2023 (General Trends from Post Covid 2019...     Russia
# 59  2019-2023 (General Trends from Post Covid 2019...        USA
#
#     GDP (in Trillions USD)  GDP per Capita (in USD)  Inflation Rate (%)  \
# 0                 2.881041                -1.846154           -0.877193
# 1                 5.031447                 7.246377           -2.515723
# 2                -7.734807                -2.663934            0.543478
# 3                -4.197698                -1.412714            1.229508
# 4                -5.479452                -4.109589           -6.772908
# 5                -8.633094                 1.752577            7.586207
# 6                 1.492537                -5.113078           -3.225806
# 7                -4.666667                -5.899705           -1.070664
# 8                -0.214286                -5.004812            6.008584
# 9                 4.069767                 6.435138           -0.512821
# 10               -4.819277                 2.222222           -0.333333
# 11               -3.816447                 1.665034            1.333333
# 12               -2.272727                 5.193483            4.761905
# 13                8.791209                -4.660194           -5.070994
# 14                0.702247                -4.321608            0.854701
# 15               -1.724138                 5.159959            7.103825
# 16                3.184713                -1.457726            2.684564
# 17               -5.072127                -0.190840            5.429864
# 18                0.751880                 2.481903           -0.680272
# 19                2.517986                -7.418112           -4.008016
# 20                6.209386                -4.859086            2.928870
# 21               -8.241758                 6.069959           -0.526316
# 22                0.641026                -2.057613           -3.571429
# 23               -1.431298                 0.588813            1.702128
# 24               -1.550388                -1.725888            3.355705
# 25                1.086957                 1.649485            1.952278
# 26               -1.436782                 3.459119            0.000000
# 27               -1.142857                -1.913394            3.867403
# 28                5.128205                 1.114488            3.225806
# 29                3.876349                -4.326450           -3.083700
# 30               -5.147059                -1.812977            1.369863
# 31                1.045296                 3.935419           -1.702128
# 32                3.968816                -0.097943           -4.897959
# 33                0.555556                 0.917431            7.103825
# 34                0.000000                 0.816327            3.257329
# 35               -0.419972                -2.113353            4.977376
# 36                8.527132                -3.484995           -6.493506
# 37               -1.346801                -2.240326            7.692308
# 38                1.185495                 6.617647            6.355932
# 39                2.339181                -0.196271           -3.061224
# 40                1.234568                -4.635108           -0.980392
# 41                8.725490                -0.860421            1.287554
# 42               -1.459854                -5.789990           -2.597403
# 43                1.779359                -4.889741           -2.553191
# 44                3.986014                 7.164790            0.806452
# 45                4.000000                 5.312500            3.867403
# 46                0.617284                -0.817996            5.050505
# 47                7.262022                -5.000000            4.072398
# 48               -4.511278                 1.361257            0.000000
# 49               -0.711744                -4.085603           -3.092784
# 50               -6.412005                -5.096154           -8.400000
# 51               -0.574713                -6.346154            1.621622
# 52                0.000000                 3.634476            8.108108
# 53               -1.397299                -1.518219           -5.172414
# 54               -8.633094                -0.206186            6.206897
# 55               -4.452055                -3.522505           -6.374502
# 56               -7.109005                -0.403633           -6.147541
# 57               -4.419890                -0.204918            2.173913
# 58                3.144654                 3.312629            0.628931
# 59               -1.626394                -0.205128           -3.508772
#
#     Population (in Millions)  Population Growth Rate (%)  \
# 0                   4.995442                   -4.918033
# 1                  -1.417004                    0.000000
# 2                   0.620068                    1.149425
# 3                  -0.521377                   -3.333333
# 4                   5.925156                    3.125000
# 5                   1.171875                   -3.703704
# 6                   5.104603                    0.775194
# 7                  -0.415369                    6.185567
# 8                  -0.486383                    3.333333
# 9                  -8.018624                    2.150538
# 10                 -7.047995                    0.000000
# 11                  0.291903                   -8.064516
# 12                 -2.820306                    6.349206
# 13                  1.015228                    7.216495
# 14                  6.631976                   -6.451613
# 15                 -0.509930                    5.813953
# 16                  5.076033                    0.000000
# 17                  5.083365                   -6.557377
# 18                 -0.427517                    0.000000
# 19                  2.961500                   -1.941748
# 20                 -8.699934                   -6.666667
# 21                 -5.730511                    4.545455
# 22                  8.276161                    0.000000
# 23                 -4.510504                   -4.918033
# 24                 -7.123810                    0.740741
# 25                  0.788177                   -0.961538
# 26                  0.700286                    0.000000
# 27                 -3.628486                   -1.063830
# 28                 -2.959578                    0.000000
# 29                  6.620724                   -4.838710
# 30                  4.061738                    0.757576
# 31                 -2.251791                    7.142857
# 32                  0.625149                    0.000000
# 33                 -1.761304                   -2.197802
# 34                  6.384360                    0.000000
# 35                 -1.488113                    5.084746
# 36                  2.072968                   -1.492537
# 37                  0.502513                   -7.692308
# 38                 -2.040958                    3.448276
# 39                 -0.890208                   -4.395604
# 40                  0.489197                    0.000000
# 41                 -1.875932                    7.017544
# 42                  3.391232                   -3.100775
# 43                 -8.149569                   -4.854369
# 44                 -2.716222                    0.000000
# 45                  3.077335                   -5.434783
# 46                 -3.393214                    0.000000
# 47                  0.489193                    7.017544
# 48                 -0.773301                    0.740741
# 49                  5.246914                    0.980392
# 50                 -1.467706                   -6.451613
# 51                 -6.070203                   -1.063830
# 52                 -0.310537                    0.000000
# 53                  5.225444                   -4.838710
# 54                 -4.765625                    0.740741
# 55                  6.340956                    7.291667
# 56                  5.005669                   -3.333333
# 57                  0.310034                    6.896552
# 58                 -3.643725                    0.000000
# 59                  8.950297                   -3.278689
#
#     Life Expectancy (Years)  Healthcare Expenditure per Capita (USD)  \
# 0                  3.424570                                -3.389831
# 1                  2.988048                                -0.287272
# 2                 -4.623669                                 3.014553
# 3                  6.822165                                 2.564103
# 4                  1.872499                                 6.019307
# 5                 -6.732765                                -3.625954
# 6                 -3.704569                                 0.000000
# 7                 -4.181282                                -5.759722
# 8                 -5.499622                                 6.250000
# 9                  7.036944                                -0.411523
# 10                 8.815545                                -4.560814
# 11                 5.301858                                 2.030457
# 12                -4.066458                                 6.735751
# 13                 2.321869                                 0.402522
# 14                -4.673130                                -4.321608
# 15                -7.521968                                 6.014271
# 16                 0.190166                                -0.480295
# 17                -1.554133                                -2.146341
# 18                -2.353495                                 6.038895
# 19                -2.253521                                -4.984632
# 20                -7.792697                                 7.628004
# 21                -0.521098                                 2.774923
# 22                 0.483286                                -1.402316
# 23                -1.119979                                -3.206413
# 24                 2.671427                                 2.050781
# 25                 4.658802                                 5.682134
# 26                -3.727117                                -4.780876
# 27                -7.142857                                -5.135659
# 28                 2.226242                                -0.963391
# 29                 5.147921                                 0.609756
# 30                -2.334914                                -7.350097
# 31                -1.507683                                 4.466572
# 32                 6.735191                                 5.419223
# 33                 0.871306                                 3.507014
# 34                -3.909222                                -2.833041
# 35                 0.476831                                 6.820567
# 36                 0.096887                                -1.844660
# 37                 2.949936                                -6.347722
# 38                -1.395046                                 1.890756
# 39                 4.472317                                -6.346154
# 40                 0.488069                                -5.492247
# 41                 5.770761                                -2.891326
# 42                -0.319725                                -5.582762
# 43                -3.445255                                -9.349700
# 44                 2.786418                                 3.115578
# 45                 3.513481                                 2.710843
# 46                -5.590817                                 6.534282
# 47                 8.066414                                -6.011450
# 48                -4.302926                                 5.130785
# 49                 5.208646                                 1.264643
# 50                 0.315631                                -6.640625
# 51                 0.520569                                -6.136146
# 52                -3.430599                                -1.247896
# 53                -1.260556                                 0.917431
# 54                -3.850588                                -0.286260
# 55                 0.185820                                 7.992618
# 56                -1.442632                                -1.948718
# 57                -7.327637                                 1.767152
# 58                 4.538987                                -1.247896
# 59                 2.711649                                -1.296112
#
#     Doctor-to-Patient Ratio  Unemployment Rate (%)  \
# 0                  1.550388              -5.699482
# 1                  0.729927               1.354402
# 2                 -1.324503               5.607477
# 3                  5.649718               5.247813
# 4                  3.448276               1.540616
# 5                  0.564972               4.703476
# 6                 -5.337079               2.600000
# 7                  1.098901               5.922865
# 8                 -1.086957              -6.756757
# 9                 -9.539474              -2.154399
# 10                 0.253807               1.528384
# 11                -7.407407               5.219780
# 12                -2.994012               0.835073
# 13                 1.086957              -4.330709
# 14                 8.670520               1.420455
# 15                -2.380952               2.626970
# 16                -1.438849               2.330508
# 17                 0.371747              -4.301075
# 18                 4.242424              -0.801603
# 19                 2.298851               0.388601
# 20                 6.358382               2.452316
# 21                -1.060071              -7.534247
# 22                -6.490385               1.315789
# 23                -2.734375              -1.822917
# 24                 7.621951              -3.455285
# 25                 5.681818              -4.787234
# 26                -1.630435               1.129944
# 27                -1.418440              -3.886926
# 28                 2.222222               1.956522
# 29                -8.823529              -6.578947
# 30                 0.000000              -1.730769
# 31                 8.045977               1.513067
# 32                -5.494505               3.779070
# 33                 2.076125               0.000000
# 34                 6.201550               0.911162
# 35                -2.734375              -4.473684
# 36                -0.308642               5.383023
# 37                -2.150538               6.035665
# 38                -2.127660              -2.240896
# 39                 2.090592              -3.754266
# 40                -4.136253              -3.726708
# 41                -7.407407               2.528090
# 42                -3.779070               2.702703
# 43                -5.434783               0.134771
# 44                -1.685393               8.092486
# 45                 1.792115              -3.030303
# 46                -1.291990               1.304348
# 47                -1.953125               1.108033
# 48                 7.294833              -5.753968
# 49                 5.681818              -3.243243
# 50                 4.624277               0.561798
# 51                -6.397306              -4.895105
# 52                 7.812500              -1.470588
# 53                -2.745098              -5.585106
# 54                -0.282486              -2.862986
# 55                 6.896552               0.280112
# 56                 2.259887               4.373178
# 57                -7.947020               1.682243
# 58                 0.729927               5.869074
# 59                -3.875969              -8.031088
#
#     Labor Force Participation Rate (%)  Crime Rate (per 100,000)
# 0                            -1.252678                 -1.761252
# 1                            -0.791296                  5.601660
# 2                            -4.830406                 -3.115871
# 3                             7.294041                 -8.595989
# 4                             4.824121                  1.789264
# 5                             5.478166                 -2.017291
# 6                            -1.248245                  1.453488
# 7                            -1.305221                 -2.439024
# 8                             0.409098                 -5.470250
# 9                            -2.079829                  1.859100
# 10                           -0.767018                 -1.442308
# 11                            0.602601                 -5.962854
# 12                            9.856916                 -2.256410
# 13                            0.000000                  7.453416
# 14                            7.952847                 -8.126195
# 15                           -3.447752                  5.566802
# 16                            4.257529                 -3.554275
# 17                            0.000000                 -8.716475
# 18                           -3.065078                  2.845927
# 19                            7.966457                  4.811715
# 20                            0.414662                  1.398601
# 21                           -2.136182                 -1.243523
# 22                           -5.500982                  4.489796
# 23                            4.381614                 -3.068073
# 24                            2.441551                 -3.157895
# 25                           -6.128405                 -3.118712
# 26                            4.396825                 -6.293019
# 27                            0.701372                  1.009082
# 28                           -0.912779                 -7.550823
# 29                           -3.987635                 -6.072478
# 30                           -0.418280                  6.160164
# 31                            2.371134                  2.066929
# 32                            3.168156                  0.198807
# 33                           -2.561771                  4.083665
# 34                            4.742684                  5.509356
# 35                           -1.326861                 -3.225806
# 36                           -2.865412                  1.469045
# 37                            1.198801                 -3.564547
# 38                            1.645647                  5.827263
# 39                            5.222589                 -4.410355
# 40                           -4.581673                 -1.095618
# 41                           -7.338747                  4.931794
# 42                            7.496843                 -0.729167
# 43                            0.872093                 -6.346154
# 44                            4.682706                 -5.258126
# 45                           -3.773873                 -3.036437
# 46                            2.142857                 -0.303644
# 47                           -3.492063                 -1.404213
# 48                            9.143938                  1.301301
# 49                           -2.228977                 -7.581574
# 50                           -0.197269                 -2.256410
# 51                           -2.268946                  3.516029
# 52                           -3.838583                 -5.069583
# 53                            1.553049                 -3.907816
# 54                            8.358116                 -2.785783
# 55                           -3.015075                 -4.274354
# 56                            7.082384                 -8.978032
# 57                           -2.165354                 -2.531646
# 58                           -3.363007                 -0.933610
# 59                            2.389979                 -6.164384

# %%
json_data = countries_df.to_json(orient="records", indent=4)

output_path = "Resources/percentages_data.json"
growth_rate_df.to_json(output_path, orient="records", indent=4)
